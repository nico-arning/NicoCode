# %%
#!pip install seaborn

# %%
import boto3
import os
import fnmatch

def download_files_from_s3(bucket_name, directory_pattern, local_folder, aws_access_key_id, aws_secret_access_key):
    # Initialize a session using your AWS credentials
    s3 = boto3.client(
        's3',
        aws_access_key_id=aws_access_key_id,
        aws_secret_access_key=aws_secret_access_key
    )

    # Ensure the local folder exists
    if not os.path.exists(local_folder):
        os.makedirs(local_folder)

    # List objects within the specified bucket
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix='workspace/profiles')
    
    if 'Contents' in response:
        for obj in response['Contents']:
            file_key = obj['Key']
            #print(file_key)
            #print("Directory pattern:", directory_pattern)
            # Check if the file_key matches the directory pattern
            if directory_pattern in file_key:
                print(f"Found file: {file_key}")
                # Create local file path while preserving the S3 folder structure
                local_file_path = os.path.join(local_folder, os.path.relpath(file_key, start=''))
                
                # Ensure the local directory exists
                local_dir = os.path.dirname(local_file_path)
                if not os.path.exists(local_dir):
                    os.makedirs(local_dir)

                # Download the file
                s3.download_file(bucket_name, file_key, local_file_path)
                print(f"Downloaded {file_key} to {local_file_path}")

# Example usage
bucket_name = 'picasso-monheim'
directory_pattern = "MoA1064-week"
local_folder = '/home/ubuntu/picasso_qc/profiles/'

# Replace your AWS credentials here
aws_access_key_id = "AKIARH5WYQXVEN776NUF"
aws_secret_access_key = "WMSFOqBne7XTU1VnerCfMwFSatmhhTQcz73UR5aZ"

download_files_from_s3(bucket_name, directory_pattern, local_folder, aws_access_key_id, aws_secret_access_key)
# Out:
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_DMSO4/QC_MoA1064_week1_24h_DMSO4.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_DMSO4/QC_MoA1064_week1_24h_DMSO4.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_DMSO4/QC_MoA1064_week1_24h_DMSO4.csv.gz
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd1/QC_MoA1064_week1_24h_cpd1.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd1/QC_MoA1064_week1_24h_cpd1.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd1/QC_MoA1064_week1_24h_cpd1.csv.gz
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd2/QC_MoA1064_week1_24h_cpd2.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd2/QC_MoA1064_week1_24h_cpd2.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd2/QC_MoA1064_week1_24h_cpd2.csv.gz
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd3/QC_MoA1064_week1_24h_cpd3.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd3/QC_MoA1064_week1_24h_cpd3.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_24h_cpd3/QC_MoA1064_week1_24h_cpd3.csv.gz
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_DMSO4/QC_MoA1064_week1_6h_DMSO4.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_DMSO4/QC_MoA1064_week1_6h_DMSO4.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_DMSO4/QC_MoA1064_week1_6h_DMSO4.csv.gz
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd1/QC_MoA1064_week1_6h_cpd1.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd1/QC_MoA1064_week1_6h_cpd1.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd1/QC_MoA1064_week1_6h_cpd1.csv.gz
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd2/QC_MoA1064_week1_6h_cpd2.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd2/QC_MoA1064_week1_6h_cpd2.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd2/QC_MoA1064_week1_6h_cpd2.csv.gz
# Found file: workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd3/QC_MoA1064_week1_6h_cpd3.csv.gz
# Downloaded workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd3/QC_MoA1064_week1_6h_cpd3.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week1/QC_MoA1064_week1_6h_cpd3/QC_MoA1064_week1_6h_cpd3.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_DMSO4/QC_MoA1064_week2_24h_DMSO4.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_DMSO4/QC_MoA1064_week2_24h_DMSO4.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_DMSO4/QC_MoA1064_week2_24h_DMSO4.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd1/QC_MoA1064_week2_24h_cpd1.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd1/QC_MoA1064_week2_24h_cpd1.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd1/QC_MoA1064_week2_24h_cpd1.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd2/QC_MoA1064_week2_24h_cpd2.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd2/QC_MoA1064_week2_24h_cpd2.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd2/QC_MoA1064_week2_24h_cpd2.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd3/QC_MoA1064_week2_24h_cpd3.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd3/QC_MoA1064_week2_24h_cpd3.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_24h_cpd3/QC_MoA1064_week2_24h_cpd3.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_DMSO4/QC_MoA1064_week2_6h_DMSO4.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_DMSO4/QC_MoA1064_week2_6h_DMSO4.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_DMSO4/QC_MoA1064_week2_6h_DMSO4.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd1/QC_MoA1064_week2_6h_cpd1.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd1/QC_MoA1064_week2_6h_cpd1.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd1/QC_MoA1064_week2_6h_cpd1.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd2/QC_MoA1064_week2_6h_cpd2.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd2/QC_MoA1064_week2_6h_cpd2.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd2/QC_MoA1064_week2_6h_cpd2.csv.gz
# Found file: workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd3/QC_MoA1064_week2_6h_cpd3.csv.gz
# Downloaded workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd3/QC_MoA1064_week2_6h_cpd3.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week2/QC_MoA1064_week2_6h_cpd3/QC_MoA1064_week2_6h_cpd3.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_DMSO4/QC_MoA1064_week3_24h_DMSO4.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_DMSO4/QC_MoA1064_week3_24h_DMSO4.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_DMSO4/QC_MoA1064_week3_24h_DMSO4.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd1/QC_MoA1064_week3_24h_cpd1.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd1/QC_MoA1064_week3_24h_cpd1.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd1/QC_MoA1064_week3_24h_cpd1.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd2/QC_MoA1064_week3_24h_cpd2.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd2/QC_MoA1064_week3_24h_cpd2.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd2/QC_MoA1064_week3_24h_cpd2.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd3/QC_MoA1064_week3_24h_cpd3.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd3/QC_MoA1064_week3_24h_cpd3.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_24h_cpd3/QC_MoA1064_week3_24h_cpd3.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_DMSO4/QC_MoA1064_week3_6h_DMSO4.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_DMSO4/QC_MoA1064_week3_6h_DMSO4.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_DMSO4/QC_MoA1064_week3_6h_DMSO4.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd1/QC_MoA1064_week3_6h_cpd1.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd1/QC_MoA1064_week3_6h_cpd1.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd1/QC_MoA1064_week3_6h_cpd1.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd2/QC_MoA1064_week3_6h_cpd2.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd2/QC_MoA1064_week3_6h_cpd2.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd2/QC_MoA1064_week3_6h_cpd2.csv.gz
# Found file: workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd3/QC_MoA1064_week3_6h_cpd3.csv.gz
# Downloaded workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd3/QC_MoA1064_week3_6h_cpd3.csv.gz to /home/ubuntu/picasso_qc/profiles/workspace/profiles/MoA1064-week3/QC_MoA1064_week3_6h_cpd3/QC_MoA1064_week3_6h_cpd3.csv.gz

# %%
import pandas as pd
df = pd.read_excel("meta_data_cpd.xlsx", sheet_name="Sheet1", header = None)

df = df.reset_index().melt(id_vars='index')

# Combine row header and column header into a single column "Wells"
df['Well_row'] = df['index']
df["Well_col"] = df['variable']
# Select the relevant columns
df[['Treatment', 'Concentration']] = df['value'].astype(str).str.split(expand=True)
df = df[[ 'Well_row', 'Well_col', 'Treatment', 'Concentration']]
df.loc[df["Treatment"] == "DMSO", "Concentration"] = 0
max_row = df["Well_row"].max()
max_col = df["Well_col"].max()
df["well_row_distance_to_edge"] = df["Well_row"].apply(lambda x: min(x, max_row - x))
df["well_col_distance_to_edge"] = df["Well_col"].apply(lambda x: min(x, max_col - x))
df["Well_row_alphabetical"] = [ list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')[x]  for x in df["Well_row"]]
df["Well"] = df["Well_row_alphabetical"] + (df["Well_col"] +1).astype(str).str.zfill(2)

# %%
df["Ring_position"] = 0
for i, row in df.iterrows():
    df.at[i, "Ring_position"] = min(row["well_row_distance_to_edge"], row["well_col_distance_to_edge"])
   
df["Inside_outside"] = "Outside"
df.loc[df["Ring_position"] <= df["Ring_position"].max() // 2, "Inside_outside"] = "Inside"
for quartile in [2, 4, 8]:
    df[f"row_quantiles_{quartile}"] = pd.qcut(df["Well_row"], quartile, labels=[f"row_Q{i}" for i in range(1, quartile + 1)]).astype(str)
    df[f"col_quantiles_{quartile}"] = pd.qcut(df["Well_col"], quartile, labels=[f"col_Q{i}" for i in range(1, quartile + 1)]).astype(str)
    df[f"plate_quantiles_{quartile}"] = df[f"row_quantiles_{quartile}"] + "_" + df[f"col_quantiles_{quartile}"]
df.columns = [ "Metadata_" + str(x) for x in df.columns]

df.to_csv("Meta_data_parsed.csv", index = False)

# %%
from glob import glob
cellprofiler_tables = list(glob("/home/ubuntu/picasso_qc/profiles/*.csv.gz", recursive=True))

# %%
import pandas as pd
import numpy as np
import glob
from sklearn.preprocessing import MinMaxScaler

concat_list = []

for table in cellprofiler_tables:
    table_split = table.split("/")
    experiment_name = table_split[4]
    week = experiment_name.split("_")[3]
    confocal = experiment_name.split("_")[4]
    
    experiment_name2 = table_split[5]
    cmpd = experiment_name2.split("_")[2]
    table_name = table_split[6]
    dmso_or_cpd = "Cmpd"
    if cmpd == "DMSO":
        dmso_or_cpd = "DMSO"
    print(week, confocal, cmpd, table_name)
    
    profile_df = pd.read_csv(table, compression='gzip')
    numerical_cols = profile_df.select_dtypes(include=['float64', 'int64']).columns
    
    profile_df = profile_df.apply(lambda x: x.replace(np.inf, x[x != np.inf].max()))

    scaler = MinMaxScaler()
    profile_df[numerical_cols] = scaler.fit_transform(profile_df[numerical_cols])
    
    # Create new columns in one step
    new_columns = pd.DataFrame({
        "Metadata_DMSO_or_Cmpd": dmso_or_cpd,
        "Metadata_Week": week,
        "Metadata_Confocal_or_Nonconfocal": confocal,
        "Metadata_Replicate": cmpd
    }, index=profile_df.index)
    
    profile_df = pd.concat([profile_df, new_columns], axis=1)
    profile_df = profile_df.merge(df, how="left", on="Metadata_Well")
    
    concat_list.append(profile_df)

# Combine all DataFrames in concat_list
final_df = pd.concat(concat_list, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 11
#       9 table_split = table.split("/")
#      10 experiment_name = table_split[4]
# ---> 11 week = experiment_name.split("_")[3]
#      12 confocal = experiment_name.split("_")[4]
#      14 experiment_name2 = table_split[5]
#
# IndexError: list index out of range

# %%
big_df = pd.concat(concat_list, ignore_index=True)

# %%
big_df.to_csv("all_plate_df.csv", index = False)
#big_df.to_csv("all_plate_df.csv.gz", index = False, compression='gzip')

# %%
big_df["Week"]
# Out:
# 0       Woche3
# 1       Woche3
# 2       Woche3
# 3       Woche3
# 4       Woche3
#          ...
# 9210    Woche2
# 9211    Woche2
# 9212    Woche2
# 9213    Woche2
# 9214    Woche2
# Name: Week, Length: 9215, dtype: object

# %%
big_df.columns.to_list()
# Out:
# ['Metadata_Plate',
#  'Metadata_Well',
#  'Metadata_Site_Count',
#  'Metadata_Count_Cells',
#  'Metadata_Count_CellsIncludingEdges',
#  'Metadata_Count_Cytoplasm',
#  'Metadata_Count_Nuclei',
#  'Metadata_Count_NucleiIncludingEdges',
#  'Metadata_Object_Count',
#  'Image_Granularity_10_AGP',
#  'Image_Granularity_10_DNA',
#  'Image_Granularity_10_ER',
#  'Image_Granularity_10_Mito',
#  'Image_Granularity_10_RNA',
#  'Image_Granularity_11_AGP',
#  'Image_Granularity_11_DNA',
#  'Image_Granularity_11_ER',
#  'Image_Granularity_11_Mito',
#  'Image_Granularity_11_RNA',
#  'Image_Granularity_12_AGP',
#  'Image_Granularity_12_DNA',
#  'Image_Granularity_12_ER',
#  'Image_Granularity_12_Mito',
#  'Image_Granularity_12_RNA',
#  'Image_Granularity_13_AGP',
#  'Image_Granularity_13_DNA',
#  'Image_Granularity_13_ER',
#  'Image_Granularity_13_Mito',
#  'Image_Granularity_13_RNA',
#  'Image_Granularity_14_AGP',
#  'Image_Granularity_14_DNA',
#  'Image_Granularity_14_ER',
#  'Image_Granularity_14_Mito',
#  'Image_Granularity_14_RNA',
#  'Image_Granularity_15_AGP',
#  'Image_Granularity_15_DNA',
#  'Image_Granularity_15_ER',
#  'Image_Granularity_15_Mito',
#  'Image_Granularity_15_RNA',
#  'Image_Granularity_16_AGP',
#  'Image_Granularity_16_DNA',
#  'Image_Granularity_16_ER',
#  'Image_Granularity_16_Mito',
#  'Image_Granularity_16_RNA',
#  'Image_Granularity_1_AGP',
#  'Image_Granularity_1_DNA',
#  'Image_Granularity_1_ER',
#  'Image_Granularity_1_Mito',
#  'Image_Granularity_1_RNA',
#  'Image_Granularity_2_AGP',
#  'Image_Granularity_2_DNA',
#  'Image_Granularity_2_ER',
#  'Image_Granularity_2_Mito',
#  'Image_Granularity_2_RNA',
#  'Image_Granularity_3_AGP',
#  'Image_Granularity_3_DNA',
#  'Image_Granularity_3_ER',
#  'Image_Granularity_3_Mito',
#  'Image_Granularity_3_RNA',
#  'Image_Granularity_4_AGP',
#  'Image_Granularity_4_DNA',
#  'Image_Granularity_4_ER',
#  'Image_Granularity_4_Mito',
#  'Image_Granularity_4_RNA',
#  'Image_Granularity_5_AGP',
#  'Image_Granularity_5_DNA',
#  'Image_Granularity_5_ER',
#  'Image_Granularity_5_Mito',
#  'Image_Granularity_5_RNA',
#  'Image_Granularity_6_AGP',
#  'Image_Granularity_6_DNA',
#  'Image_Granularity_6_ER',
#  'Image_Granularity_6_Mito',
#  'Image_Granularity_6_RNA',
#  'Image_Granularity_7_AGP',
#  'Image_Granularity_7_DNA',
#  'Image_Granularity_7_ER',
#  'Image_Granularity_7_Mito',
#  'Image_Granularity_7_RNA',
#  'Image_Granularity_8_AGP',
#  'Image_Granularity_8_DNA',
#  'Image_Granularity_8_ER',
#  'Image_Granularity_8_Mito',
#  'Image_Granularity_8_RNA',
#  'Image_Granularity_9_AGP',
#  'Image_Granularity_9_DNA',
#  'Image_Granularity_9_ER',
#  'Image_Granularity_9_Mito',
#  'Image_Granularity_9_RNA',
#  'Image_ImageQuality_Correlation_OrigAGP_10',
#  'Image_ImageQuality_Correlation_OrigAGP_20',
#  'Image_ImageQuality_Correlation_OrigAGP_5',
#  'Image_ImageQuality_Correlation_OrigAGP_50',
#  'Image_ImageQuality_Correlation_OrigDNA_10',
#  'Image_ImageQuality_Correlation_OrigDNA_20',
#  'Image_ImageQuality_Correlation_OrigDNA_5',
#  'Image_ImageQuality_Correlation_OrigDNA_50',
#  'Image_ImageQuality_Correlation_OrigER_10',
#  'Image_ImageQuality_Correlation_OrigER_20',
#  'Image_ImageQuality_Correlation_OrigER_5',
#  'Image_ImageQuality_Correlation_OrigER_50',
#  'Image_ImageQuality_Correlation_OrigMito_10',
#  'Image_ImageQuality_Correlation_OrigMito_20',
#  'Image_ImageQuality_Correlation_OrigMito_5',
#  'Image_ImageQuality_Correlation_OrigMito_50',
#  'Image_ImageQuality_Correlation_OrigRNA_10',
#  'Image_ImageQuality_Correlation_OrigRNA_20',
#  'Image_ImageQuality_Correlation_OrigRNA_5',
#  'Image_ImageQuality_Correlation_OrigRNA_50',
#  'Image_ImageQuality_FocusScore_OrigAGP',
#  'Image_ImageQuality_FocusScore_OrigDNA',
#  'Image_ImageQuality_FocusScore_OrigER',
#  'Image_ImageQuality_FocusScore_OrigMito',
#  'Image_ImageQuality_FocusScore_OrigRNA',
#  'Image_ImageQuality_LocalFocusScore_OrigAGP_10',
#  'Image_ImageQuality_LocalFocusScore_OrigAGP_20',
#  'Image_ImageQuality_LocalFocusScore_OrigAGP_5',
#  'Image_ImageQuality_LocalFocusScore_OrigAGP_50',
#  'Image_ImageQuality_LocalFocusScore_OrigDNA_10',
#  'Image_ImageQuality_LocalFocusScore_OrigDNA_20',
#  'Image_ImageQuality_LocalFocusScore_OrigDNA_5',
#  'Image_ImageQuality_LocalFocusScore_OrigDNA_50',
#  'Image_ImageQuality_LocalFocusScore_OrigER_10',
#  'Image_ImageQuality_LocalFocusScore_OrigER_20',
#  'Image_ImageQuality_LocalFocusScore_OrigER_5',
#  'Image_ImageQuality_LocalFocusScore_OrigER_50',
#  'Image_ImageQuality_LocalFocusScore_OrigMito_10',
#  'Image_ImageQuality_LocalFocusScore_OrigMito_20',
#  'Image_ImageQuality_LocalFocusScore_OrigMito_5',
#  'Image_ImageQuality_LocalFocusScore_OrigMito_50',
#  'Image_ImageQuality_LocalFocusScore_OrigRNA_10',
#  'Image_ImageQuality_LocalFocusScore_OrigRNA_20',
#  'Image_ImageQuality_LocalFocusScore_OrigRNA_5',
#  'Image_ImageQuality_LocalFocusScore_OrigRNA_50',
#  'Image_ImageQuality_MADIntensity_OrigAGP',
#  'Image_ImageQuality_MADIntensity_OrigDNA',
#  'Image_ImageQuality_MADIntensity_OrigER',
#  'Image_ImageQuality_MADIntensity_OrigMito',
#  'Image_ImageQuality_MADIntensity_OrigRNA',
#  'Image_ImageQuality_MaxIntensity_OrigAGP',
#  'Image_ImageQuality_MaxIntensity_OrigDNA',
#  'Image_ImageQuality_MaxIntensity_OrigER',
#  'Image_ImageQuality_MaxIntensity_OrigMito',
#  'Image_ImageQuality_MaxIntensity_OrigRNA',
#  'Image_ImageQuality_MeanIntensity_OrigAGP',
#  'Image_ImageQuality_MeanIntensity_OrigDNA',
#  'Image_ImageQuality_MeanIntensity_OrigER',
#  'Image_ImageQuality_MeanIntensity_OrigMito',
#  'Image_ImageQuality_MeanIntensity_OrigRNA',
#  'Image_ImageQuality_MedianIntensity_OrigAGP',
#  'Image_ImageQuality_MedianIntensity_OrigDNA',
#  'Image_ImageQuality_MedianIntensity_OrigER',
#  'Image_ImageQuality_MedianIntensity_OrigMito',
#  'Image_ImageQuality_MedianIntensity_OrigRNA',
#  'Image_ImageQuality_MinIntensity_OrigAGP',
#  'Image_ImageQuality_MinIntensity_OrigDNA',
#  'Image_ImageQuality_MinIntensity_OrigER',
#  'Image_ImageQuality_MinIntensity_OrigMito',
#  'Image_ImageQuality_MinIntensity_OrigRNA',
#  'Image_ImageQuality_PercentMaximal_OrigAGP',
#  'Image_ImageQuality_PercentMaximal_OrigDNA',
#  'Image_ImageQuality_PercentMaximal_OrigER',
#  'Image_ImageQuality_PercentMaximal_OrigMito',
#  'Image_ImageQuality_PercentMaximal_OrigRNA',
#  'Image_ImageQuality_PercentMinimal_OrigAGP',
#  'Image_ImageQuality_PercentMinimal_OrigDNA',
#  'Image_ImageQuality_PercentMinimal_OrigER',
#  'Image_ImageQuality_PercentMinimal_OrigMito',
#  'Image_ImageQuality_PercentMinimal_OrigRNA',
#  'Image_ImageQuality_PowerLogLogSlope_OrigAGP',
#  'Image_ImageQuality_PowerLogLogSlope_OrigDNA',
#  'Image_ImageQuality_PowerLogLogSlope_OrigER',
#  'Image_ImageQuality_PowerLogLogSlope_OrigMito',
#  'Image_ImageQuality_PowerLogLogSlope_OrigRNA',
#  'Image_ImageQuality_Scaling_OrigAGP',
#  'Image_ImageQuality_Scaling_OrigDNA',
#  'Image_ImageQuality_Scaling_OrigER',
#  'Image_ImageQuality_Scaling_OrigMito',
#  'Image_ImageQuality_Scaling_OrigRNA',
#  'Image_ImageQuality_StdIntensity_OrigAGP',
#  'Image_ImageQuality_StdIntensity_OrigDNA',
#  'Image_ImageQuality_StdIntensity_OrigER',
#  'Image_ImageQuality_StdIntensity_OrigMito',
#  'Image_ImageQuality_StdIntensity_OrigRNA',
#  'Image_ImageQuality_ThresholdOtsu_OrigDNA_2W',
#  'Image_ImageQuality_ThresholdOtsu_OrigRNA_3FW',
#  'Image_ImageQuality_TotalArea_OrigAGP',
#  'Image_ImageQuality_TotalArea_OrigDNA',
#  'Image_ImageQuality_TotalArea_OrigER',
#  'Image_ImageQuality_TotalArea_OrigMito',
#  'Image_ImageQuality_TotalArea_OrigRNA',
#  'Image_ImageQuality_TotalIntensity_OrigAGP',
#  'Image_ImageQuality_TotalIntensity_OrigDNA',
#  'Image_ImageQuality_TotalIntensity_OrigER',
#  'Image_ImageQuality_TotalIntensity_OrigMito',
#  'Image_ImageQuality_TotalIntensity_OrigRNA',
#  'Image_Intensity_LowerQuartileIntensity_AGP',
#  'Image_Intensity_LowerQuartileIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_LowerQuartileIntensity_DNA',
#  'Image_Intensity_LowerQuartileIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_LowerQuartileIntensity_ER',
#  'Image_Intensity_LowerQuartileIntensity_ER__BackgroundOnly',
#  'Image_Intensity_LowerQuartileIntensity_Mito',
#  'Image_Intensity_LowerQuartileIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_LowerQuartileIntensity_RNA',
#  'Image_Intensity_LowerQuartileIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_MADIntensity_AGP',
#  'Image_Intensity_MADIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_MADIntensity_DNA',
#  'Image_Intensity_MADIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_MADIntensity_ER',
#  'Image_Intensity_MADIntensity_ER__BackgroundOnly',
#  'Image_Intensity_MADIntensity_Mito',
#  'Image_Intensity_MADIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_MADIntensity_RNA',
#  'Image_Intensity_MADIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_MaxIntensity_AGP',
#  'Image_Intensity_MaxIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_MaxIntensity_DNA',
#  'Image_Intensity_MaxIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_MaxIntensity_ER',
#  'Image_Intensity_MaxIntensity_ER__BackgroundOnly',
#  'Image_Intensity_MaxIntensity_Mito',
#  'Image_Intensity_MaxIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_MaxIntensity_RNA',
#  'Image_Intensity_MaxIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_MeanIntensity_AGP',
#  'Image_Intensity_MeanIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_MeanIntensity_DNA',
#  'Image_Intensity_MeanIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_MeanIntensity_ER',
#  'Image_Intensity_MeanIntensity_ER__BackgroundOnly',
#  'Image_Intensity_MeanIntensity_Mito',
#  'Image_Intensity_MeanIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_MeanIntensity_RNA',
#  'Image_Intensity_MeanIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_MedianIntensity_AGP',
#  'Image_Intensity_MedianIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_MedianIntensity_DNA',
#  'Image_Intensity_MedianIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_MedianIntensity_ER',
#  'Image_Intensity_MedianIntensity_ER__BackgroundOnly',
#  'Image_Intensity_MedianIntensity_Mito',
#  'Image_Intensity_MedianIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_MedianIntensity_RNA',
#  'Image_Intensity_MedianIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_MinIntensity_AGP',
#  'Image_Intensity_MinIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_MinIntensity_DNA',
#  'Image_Intensity_MinIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_MinIntensity_ER',
#  'Image_Intensity_MinIntensity_ER__BackgroundOnly',
#  'Image_Intensity_MinIntensity_Mito',
#  'Image_Intensity_MinIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_MinIntensity_RNA',
#  'Image_Intensity_MinIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_PercentMaximal_AGP',
#  'Image_Intensity_PercentMaximal_AGP__BackgroundOnly',
#  'Image_Intensity_PercentMaximal_DNA',
#  'Image_Intensity_PercentMaximal_DNA_BackgroundOnly',
#  'Image_Intensity_PercentMaximal_ER',
#  'Image_Intensity_PercentMaximal_ER__BackgroundOnly',
#  'Image_Intensity_PercentMaximal_Mito',
#  'Image_Intensity_PercentMaximal_Mito_BackgroundOnly',
#  'Image_Intensity_PercentMaximal_RNA',
#  'Image_Intensity_PercentMaximal_RNA_BackgroundOnly',
#  'Image_Intensity_StdIntensity_AGP',
#  'Image_Intensity_StdIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_StdIntensity_DNA',
#  'Image_Intensity_StdIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_StdIntensity_ER',
#  'Image_Intensity_StdIntensity_ER__BackgroundOnly',
#  'Image_Intensity_StdIntensity_Mito',
#  'Image_Intensity_StdIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_StdIntensity_RNA',
#  'Image_Intensity_StdIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_TotalArea_AGP',
#  'Image_Intensity_TotalArea_AGP__BackgroundOnly',
#  'Image_Intensity_TotalArea_DNA',
#  'Image_Intensity_TotalArea_DNA_BackgroundOnly',
#  'Image_Intensity_TotalArea_ER',
#  'Image_Intensity_TotalArea_ER__BackgroundOnly',
#  'Image_Intensity_TotalArea_Mito',
#  'Image_Intensity_TotalArea_Mito_BackgroundOnly',
#  'Image_Intensity_TotalArea_RNA',
#  'Image_Intensity_TotalArea_RNA_BackgroundOnly',
#  'Image_Intensity_TotalIntensity_AGP',
#  'Image_Intensity_TotalIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_TotalIntensity_DNA',
#  'Image_Intensity_TotalIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_TotalIntensity_ER',
#  'Image_Intensity_TotalIntensity_ER__BackgroundOnly',
#  'Image_Intensity_TotalIntensity_Mito',
#  'Image_Intensity_TotalIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_TotalIntensity_RNA',
#  'Image_Intensity_TotalIntensity_RNA_BackgroundOnly',
#  'Image_Intensity_UpperQuartileIntensity_AGP',
#  'Image_Intensity_UpperQuartileIntensity_AGP__BackgroundOnly',
#  'Image_Intensity_UpperQuartileIntensity_DNA',
#  'Image_Intensity_UpperQuartileIntensity_DNA_BackgroundOnly',
#  'Image_Intensity_UpperQuartileIntensity_ER',
#  'Image_Intensity_UpperQuartileIntensity_ER__BackgroundOnly',
#  'Image_Intensity_UpperQuartileIntensity_Mito',
#  'Image_Intensity_UpperQuartileIntensity_Mito_BackgroundOnly',
#  'Image_Intensity_UpperQuartileIntensity_RNA',
#  'Image_Intensity_UpperQuartileIntensity_RNA_BackgroundOnly',
#  'Image_Texture_AngularSecondMoment_AGP_10_00_256',
#  'Image_Texture_AngularSecondMoment_AGP_10_01_256',
#  'Image_Texture_AngularSecondMoment_AGP_10_02_256',
#  'Image_Texture_AngularSecondMoment_AGP_10_03_256',
#  'Image_Texture_AngularSecondMoment_AGP_3_00_256',
#  'Image_Texture_AngularSecondMoment_AGP_3_01_256',
#  'Image_Texture_AngularSecondMoment_AGP_3_02_256',
#  'Image_Texture_AngularSecondMoment_AGP_3_03_256',
#  'Image_Texture_AngularSecondMoment_AGP_5_00_256',
#  'Image_Texture_AngularSecondMoment_AGP_5_01_256',
#  'Image_Texture_AngularSecondMoment_AGP_5_02_256',
#  'Image_Texture_AngularSecondMoment_AGP_5_03_256',
#  'Image_Texture_AngularSecondMoment_DNA_10_00_256',
#  'Image_Texture_AngularSecondMoment_DNA_10_01_256',
#  'Image_Texture_AngularSecondMoment_DNA_10_02_256',
#  'Image_Texture_AngularSecondMoment_DNA_10_03_256',
#  'Image_Texture_AngularSecondMoment_DNA_3_00_256',
#  'Image_Texture_AngularSecondMoment_DNA_3_01_256',
#  'Image_Texture_AngularSecondMoment_DNA_3_02_256',
#  'Image_Texture_AngularSecondMoment_DNA_3_03_256',
#  'Image_Texture_AngularSecondMoment_DNA_5_00_256',
#  'Image_Texture_AngularSecondMoment_DNA_5_01_256',
#  'Image_Texture_AngularSecondMoment_DNA_5_02_256',
#  'Image_Texture_AngularSecondMoment_DNA_5_03_256',
#  'Image_Texture_AngularSecondMoment_ER_10_00_256',
#  'Image_Texture_AngularSecondMoment_ER_10_01_256',
#  'Image_Texture_AngularSecondMoment_ER_10_02_256',
#  'Image_Texture_AngularSecondMoment_ER_10_03_256',
#  'Image_Texture_AngularSecondMoment_ER_3_00_256',
#  'Image_Texture_AngularSecondMoment_ER_3_01_256',
#  'Image_Texture_AngularSecondMoment_ER_3_02_256',
#  'Image_Texture_AngularSecondMoment_ER_3_03_256',
#  'Image_Texture_AngularSecondMoment_ER_5_00_256',
#  'Image_Texture_AngularSecondMoment_ER_5_01_256',
#  'Image_Texture_AngularSecondMoment_ER_5_02_256',
#  'Image_Texture_AngularSecondMoment_ER_5_03_256',
#  'Image_Texture_AngularSecondMoment_Mito_10_00_256',
#  'Image_Texture_AngularSecondMoment_Mito_10_01_256',
#  'Image_Texture_AngularSecondMoment_Mito_10_02_256',
#  'Image_Texture_AngularSecondMoment_Mito_10_03_256',
#  'Image_Texture_AngularSecondMoment_Mito_3_00_256',
#  'Image_Texture_AngularSecondMoment_Mito_3_01_256',
#  'Image_Texture_AngularSecondMoment_Mito_3_02_256',
#  'Image_Texture_AngularSecondMoment_Mito_3_03_256',
#  'Image_Texture_AngularSecondMoment_Mito_5_00_256',
#  'Image_Texture_AngularSecondMoment_Mito_5_01_256',
#  'Image_Texture_AngularSecondMoment_Mito_5_02_256',
#  'Image_Texture_AngularSecondMoment_Mito_5_03_256',
#  'Image_Texture_AngularSecondMoment_RNA_10_00_256',
#  'Image_Texture_AngularSecondMoment_RNA_10_01_256',
#  'Image_Texture_AngularSecondMoment_RNA_10_02_256',
#  'Image_Texture_AngularSecondMoment_RNA_10_03_256',
#  'Image_Texture_AngularSecondMoment_RNA_3_00_256',
#  'Image_Texture_AngularSecondMoment_RNA_3_01_256',
#  'Image_Texture_AngularSecondMoment_RNA_3_02_256',
#  'Image_Texture_AngularSecondMoment_RNA_3_03_256',
#  'Image_Texture_AngularSecondMoment_RNA_5_00_256',
#  'Image_Texture_AngularSecondMoment_RNA_5_01_256',
#  'Image_Texture_AngularSecondMoment_RNA_5_02_256',
#  'Image_Texture_AngularSecondMoment_RNA_5_03_256',
#  'Image_Texture_Contrast_AGP_10_00_256',
#  'Image_Texture_Contrast_AGP_10_01_256',
#  'Image_Texture_Contrast_AGP_10_02_256',
#  'Image_Texture_Contrast_AGP_10_03_256',
#  'Image_Texture_Contrast_AGP_3_00_256',
#  'Image_Texture_Contrast_AGP_3_01_256',
#  'Image_Texture_Contrast_AGP_3_02_256',
#  'Image_Texture_Contrast_AGP_3_03_256',
#  'Image_Texture_Contrast_AGP_5_00_256',
#  'Image_Texture_Contrast_AGP_5_01_256',
#  'Image_Texture_Contrast_AGP_5_02_256',
#  'Image_Texture_Contrast_AGP_5_03_256',
#  'Image_Texture_Contrast_DNA_10_00_256',
#  'Image_Texture_Contrast_DNA_10_01_256',
#  'Image_Texture_Contrast_DNA_10_02_256',
#  'Image_Texture_Contrast_DNA_10_03_256',
#  'Image_Texture_Contrast_DNA_3_00_256',
#  'Image_Texture_Contrast_DNA_3_01_256',
#  'Image_Texture_Contrast_DNA_3_02_256',
#  'Image_Texture_Contrast_DNA_3_03_256',
#  'Image_Texture_Contrast_DNA_5_00_256',
#  'Image_Texture_Contrast_DNA_5_01_256',
#  'Image_Texture_Contrast_DNA_5_02_256',
#  'Image_Texture_Contrast_DNA_5_03_256',
#  'Image_Texture_Contrast_ER_10_00_256',
#  'Image_Texture_Contrast_ER_10_01_256',
#  'Image_Texture_Contrast_ER_10_02_256',
#  'Image_Texture_Contrast_ER_10_03_256',
#  'Image_Texture_Contrast_ER_3_00_256',
#  'Image_Texture_Contrast_ER_3_01_256',
#  'Image_Texture_Contrast_ER_3_02_256',
#  'Image_Texture_Contrast_ER_3_03_256',
#  'Image_Texture_Contrast_ER_5_00_256',
#  'Image_Texture_Contrast_ER_5_01_256',
#  'Image_Texture_Contrast_ER_5_02_256',
#  'Image_Texture_Contrast_ER_5_03_256',
#  'Image_Texture_Contrast_Mito_10_00_256',
#  'Image_Texture_Contrast_Mito_10_01_256',
#  'Image_Texture_Contrast_Mito_10_02_256',
#  'Image_Texture_Contrast_Mito_10_03_256',
#  'Image_Texture_Contrast_Mito_3_00_256',
#  'Image_Texture_Contrast_Mito_3_01_256',
#  'Image_Texture_Contrast_Mito_3_02_256',
#  'Image_Texture_Contrast_Mito_3_03_256',
#  'Image_Texture_Contrast_Mito_5_00_256',
#  'Image_Texture_Contrast_Mito_5_01_256',
#  'Image_Texture_Contrast_Mito_5_02_256',
#  'Image_Texture_Contrast_Mito_5_03_256',
#  'Image_Texture_Contrast_RNA_10_00_256',
#  'Image_Texture_Contrast_RNA_10_01_256',
#  'Image_Texture_Contrast_RNA_10_02_256',
#  'Image_Texture_Contrast_RNA_10_03_256',
#  'Image_Texture_Contrast_RNA_3_00_256',
#  'Image_Texture_Contrast_RNA_3_01_256',
#  'Image_Texture_Contrast_RNA_3_02_256',
#  'Image_Texture_Contrast_RNA_3_03_256',
#  'Image_Texture_Contrast_RNA_5_00_256',
#  'Image_Texture_Contrast_RNA_5_01_256',
#  'Image_Texture_Contrast_RNA_5_02_256',
#  'Image_Texture_Contrast_RNA_5_03_256',
#  'Image_Texture_Correlation_AGP_10_00_256',
#  'Image_Texture_Correlation_AGP_10_01_256',
#  'Image_Texture_Correlation_AGP_10_02_256',
#  'Image_Texture_Correlation_AGP_10_03_256',
#  'Image_Texture_Correlation_AGP_3_00_256',
#  'Image_Texture_Correlation_AGP_3_01_256',
#  'Image_Texture_Correlation_AGP_3_02_256',
#  'Image_Texture_Correlation_AGP_3_03_256',
#  'Image_Texture_Correlation_AGP_5_00_256',
#  'Image_Texture_Correlation_AGP_5_01_256',
#  'Image_Texture_Correlation_AGP_5_02_256',
#  'Image_Texture_Correlation_AGP_5_03_256',
#  'Image_Texture_Correlation_DNA_10_00_256',
#  'Image_Texture_Correlation_DNA_10_01_256',
#  'Image_Texture_Correlation_DNA_10_02_256',
#  'Image_Texture_Correlation_DNA_10_03_256',
#  'Image_Texture_Correlation_DNA_3_00_256',
#  'Image_Texture_Correlation_DNA_3_01_256',
#  'Image_Texture_Correlation_DNA_3_02_256',
#  'Image_Texture_Correlation_DNA_3_03_256',
#  'Image_Texture_Correlation_DNA_5_00_256',
#  'Image_Texture_Correlation_DNA_5_01_256',
#  'Image_Texture_Correlation_DNA_5_02_256',
#  'Image_Texture_Correlation_DNA_5_03_256',
#  'Image_Texture_Correlation_ER_10_00_256',
#  'Image_Texture_Correlation_ER_10_01_256',
#  'Image_Texture_Correlation_ER_10_02_256',
#  'Image_Texture_Correlation_ER_10_03_256',
#  'Image_Texture_Correlation_ER_3_00_256',
#  'Image_Texture_Correlation_ER_3_01_256',
#  'Image_Texture_Correlation_ER_3_02_256',
#  'Image_Texture_Correlation_ER_3_03_256',
#  'Image_Texture_Correlation_ER_5_00_256',
#  'Image_Texture_Correlation_ER_5_01_256',
#  'Image_Texture_Correlation_ER_5_02_256',
#  'Image_Texture_Correlation_ER_5_03_256',
#  'Image_Texture_Correlation_Mito_10_00_256',
#  'Image_Texture_Correlation_Mito_10_01_256',
#  'Image_Texture_Correlation_Mito_10_02_256',
#  'Image_Texture_Correlation_Mito_10_03_256',
#  'Image_Texture_Correlation_Mito_3_00_256',
#  'Image_Texture_Correlation_Mito_3_01_256',
#  'Image_Texture_Correlation_Mito_3_02_256',
#  'Image_Texture_Correlation_Mito_3_03_256',
#  'Image_Texture_Correlation_Mito_5_00_256',
#  'Image_Texture_Correlation_Mito_5_01_256',
#  'Image_Texture_Correlation_Mito_5_02_256',
#  'Image_Texture_Correlation_Mito_5_03_256',
#  'Image_Texture_Correlation_RNA_10_00_256',
#  'Image_Texture_Correlation_RNA_10_01_256',
#  'Image_Texture_Correlation_RNA_10_02_256',
#  'Image_Texture_Correlation_RNA_10_03_256',
#  'Image_Texture_Correlation_RNA_3_00_256',
#  'Image_Texture_Correlation_RNA_3_01_256',
#  'Image_Texture_Correlation_RNA_3_02_256',
#  'Image_Texture_Correlation_RNA_3_03_256',
#  'Image_Texture_Correlation_RNA_5_00_256',
#  'Image_Texture_Correlation_RNA_5_01_256',
#  'Image_Texture_Correlation_RNA_5_02_256',
#  'Image_Texture_Correlation_RNA_5_03_256',
#  'Image_Texture_DifferenceEntropy_AGP_10_00_256',
#  'Image_Texture_DifferenceEntropy_AGP_10_01_256',
#  'Image_Texture_DifferenceEntropy_AGP_10_02_256',
#  'Image_Texture_DifferenceEntropy_AGP_10_03_256',
#  'Image_Texture_DifferenceEntropy_AGP_3_00_256',
#  'Image_Texture_DifferenceEntropy_AGP_3_01_256',
#  'Image_Texture_DifferenceEntropy_AGP_3_02_256',
#  'Image_Texture_DifferenceEntropy_AGP_3_03_256',
#  'Image_Texture_DifferenceEntropy_AGP_5_00_256',
#  'Image_Texture_DifferenceEntropy_AGP_5_01_256',
#  'Image_Texture_DifferenceEntropy_AGP_5_02_256',
#  'Image_Texture_DifferenceEntropy_AGP_5_03_256',
#  'Image_Texture_DifferenceEntropy_DNA_10_00_256',
#  'Image_Texture_DifferenceEntropy_DNA_10_01_256',
#  'Image_Texture_DifferenceEntropy_DNA_10_02_256',
#  'Image_Texture_DifferenceEntropy_DNA_10_03_256',
#  'Image_Texture_DifferenceEntropy_DNA_3_00_256',
#  'Image_Texture_DifferenceEntropy_DNA_3_01_256',
#  'Image_Texture_DifferenceEntropy_DNA_3_02_256',
#  'Image_Texture_DifferenceEntropy_DNA_3_03_256',
#  'Image_Texture_DifferenceEntropy_DNA_5_00_256',
#  'Image_Texture_DifferenceEntropy_DNA_5_01_256',
#  'Image_Texture_DifferenceEntropy_DNA_5_02_256',
#  'Image_Texture_DifferenceEntropy_DNA_5_03_256',
#  'Image_Texture_DifferenceEntropy_ER_10_00_256',
#  'Image_Texture_DifferenceEntropy_ER_10_01_256',
#  'Image_Texture_DifferenceEntropy_ER_10_02_256',
#  'Image_Texture_DifferenceEntropy_ER_10_03_256',
#  'Image_Texture_DifferenceEntropy_ER_3_00_256',
#  'Image_Texture_DifferenceEntropy_ER_3_01_256',
#  'Image_Texture_DifferenceEntropy_ER_3_02_256',
#  'Image_Texture_DifferenceEntropy_ER_3_03_256',
#  'Image_Texture_DifferenceEntropy_ER_5_00_256',
#  'Image_Texture_DifferenceEntropy_ER_5_01_256',
#  'Image_Texture_DifferenceEntropy_ER_5_02_256',
#  'Image_Texture_DifferenceEntropy_ER_5_03_256',
#  'Image_Texture_DifferenceEntropy_Mito_10_00_256',
#  'Image_Texture_DifferenceEntropy_Mito_10_01_256',
#  'Image_Texture_DifferenceEntropy_Mito_10_02_256',
#  'Image_Texture_DifferenceEntropy_Mito_10_03_256',
#  'Image_Texture_DifferenceEntropy_Mito_3_00_256',
#  'Image_Texture_DifferenceEntropy_Mito_3_01_256',
#  'Image_Texture_DifferenceEntropy_Mito_3_02_256',
#  'Image_Texture_DifferenceEntropy_Mito_3_03_256',
#  'Image_Texture_DifferenceEntropy_Mito_5_00_256',
#  'Image_Texture_DifferenceEntropy_Mito_5_01_256',
#  'Image_Texture_DifferenceEntropy_Mito_5_02_256',
#  'Image_Texture_DifferenceEntropy_Mito_5_03_256',
#  'Image_Texture_DifferenceEntropy_RNA_10_00_256',
#  'Image_Texture_DifferenceEntropy_RNA_10_01_256',
#  'Image_Texture_DifferenceEntropy_RNA_10_02_256',
#  'Image_Texture_DifferenceEntropy_RNA_10_03_256',
#  'Image_Texture_DifferenceEntropy_RNA_3_00_256',
#  'Image_Texture_DifferenceEntropy_RNA_3_01_256',
#  'Image_Texture_DifferenceEntropy_RNA_3_02_256',
#  'Image_Texture_DifferenceEntropy_RNA_3_03_256',
#  'Image_Texture_DifferenceEntropy_RNA_5_00_256',
#  'Image_Texture_DifferenceEntropy_RNA_5_01_256',
#  'Image_Texture_DifferenceEntropy_RNA_5_02_256',
#  'Image_Texture_DifferenceEntropy_RNA_5_03_256',
#  'Image_Texture_DifferenceVariance_AGP_10_00_256',
#  'Image_Texture_DifferenceVariance_AGP_10_01_256',
#  'Image_Texture_DifferenceVariance_AGP_10_02_256',
#  'Image_Texture_DifferenceVariance_AGP_10_03_256',
#  'Image_Texture_DifferenceVariance_AGP_3_00_256',
#  'Image_Texture_DifferenceVariance_AGP_3_01_256',
#  'Image_Texture_DifferenceVariance_AGP_3_02_256',
#  'Image_Texture_DifferenceVariance_AGP_3_03_256',
#  'Image_Texture_DifferenceVariance_AGP_5_00_256',
#  'Image_Texture_DifferenceVariance_AGP_5_01_256',
#  'Image_Texture_DifferenceVariance_AGP_5_02_256',
#  'Image_Texture_DifferenceVariance_AGP_5_03_256',
#  'Image_Texture_DifferenceVariance_DNA_10_00_256',
#  'Image_Texture_DifferenceVariance_DNA_10_01_256',
#  'Image_Texture_DifferenceVariance_DNA_10_02_256',
#  'Image_Texture_DifferenceVariance_DNA_10_03_256',
#  'Image_Texture_DifferenceVariance_DNA_3_00_256',
#  'Image_Texture_DifferenceVariance_DNA_3_01_256',
#  'Image_Texture_DifferenceVariance_DNA_3_02_256',
#  'Image_Texture_DifferenceVariance_DNA_3_03_256',
#  'Image_Texture_DifferenceVariance_DNA_5_00_256',
#  'Image_Texture_DifferenceVariance_DNA_5_01_256',
#  'Image_Texture_DifferenceVariance_DNA_5_02_256',
#  'Image_Texture_DifferenceVariance_DNA_5_03_256',
#  'Image_Texture_DifferenceVariance_ER_10_00_256',
#  'Image_Texture_DifferenceVariance_ER_10_01_256',
#  'Image_Texture_DifferenceVariance_ER_10_02_256',
#  'Image_Texture_DifferenceVariance_ER_10_03_256',
#  'Image_Texture_DifferenceVariance_ER_3_00_256',
#  'Image_Texture_DifferenceVariance_ER_3_01_256',
#  'Image_Texture_DifferenceVariance_ER_3_02_256',
#  'Image_Texture_DifferenceVariance_ER_3_03_256',
#  'Image_Texture_DifferenceVariance_ER_5_00_256',
#  'Image_Texture_DifferenceVariance_ER_5_01_256',
#  'Image_Texture_DifferenceVariance_ER_5_02_256',
#  'Image_Texture_DifferenceVariance_ER_5_03_256',
#  'Image_Texture_DifferenceVariance_Mito_10_00_256',
#  'Image_Texture_DifferenceVariance_Mito_10_01_256',
#  'Image_Texture_DifferenceVariance_Mito_10_02_256',
#  'Image_Texture_DifferenceVariance_Mito_10_03_256',
#  'Image_Texture_DifferenceVariance_Mito_3_00_256',
#  'Image_Texture_DifferenceVariance_Mito_3_01_256',
#  'Image_Texture_DifferenceVariance_Mito_3_02_256',
#  'Image_Texture_DifferenceVariance_Mito_3_03_256',
#  'Image_Texture_DifferenceVariance_Mito_5_00_256',
#  'Image_Texture_DifferenceVariance_Mito_5_01_256',
#  'Image_Texture_DifferenceVariance_Mito_5_02_256',
#  'Image_Texture_DifferenceVariance_Mito_5_03_256',
#  'Image_Texture_DifferenceVariance_RNA_10_00_256',
#  'Image_Texture_DifferenceVariance_RNA_10_01_256',
#  'Image_Texture_DifferenceVariance_RNA_10_02_256',
#  'Image_Texture_DifferenceVariance_RNA_10_03_256',
#  'Image_Texture_DifferenceVariance_RNA_3_00_256',
#  'Image_Texture_DifferenceVariance_RNA_3_01_256',
#  'Image_Texture_DifferenceVariance_RNA_3_02_256',
#  'Image_Texture_DifferenceVariance_RNA_3_03_256',
#  'Image_Texture_DifferenceVariance_RNA_5_00_256',
#  'Image_Texture_DifferenceVariance_RNA_5_01_256',
#  'Image_Texture_DifferenceVariance_RNA_5_02_256',
#  'Image_Texture_DifferenceVariance_RNA_5_03_256',
#  'Image_Texture_Entropy_AGP_10_00_256',
#  'Image_Texture_Entropy_AGP_10_01_256',
#  'Image_Texture_Entropy_AGP_10_02_256',
#  'Image_Texture_Entropy_AGP_10_03_256',
#  'Image_Texture_Entropy_AGP_3_00_256',
#  'Image_Texture_Entropy_AGP_3_01_256',
#  'Image_Texture_Entropy_AGP_3_02_256',
#  'Image_Texture_Entropy_AGP_3_03_256',
#  'Image_Texture_Entropy_AGP_5_00_256',
#  'Image_Texture_Entropy_AGP_5_01_256',
#  'Image_Texture_Entropy_AGP_5_02_256',
#  'Image_Texture_Entropy_AGP_5_03_256',
#  'Image_Texture_Entropy_DNA_10_00_256',
#  'Image_Texture_Entropy_DNA_10_01_256',
#  'Image_Texture_Entropy_DNA_10_02_256',
#  'Image_Texture_Entropy_DNA_10_03_256',
#  'Image_Texture_Entropy_DNA_3_00_256',
#  'Image_Texture_Entropy_DNA_3_01_256',
#  'Image_Texture_Entropy_DNA_3_02_256',
#  'Image_Texture_Entropy_DNA_3_03_256',
#  'Image_Texture_Entropy_DNA_5_00_256',
#  'Image_Texture_Entropy_DNA_5_01_256',
#  'Image_Texture_Entropy_DNA_5_02_256',
#  'Image_Texture_Entropy_DNA_5_03_256',
#  'Image_Texture_Entropy_ER_10_00_256',
#  'Image_Texture_Entropy_ER_10_01_256',
#  'Image_Texture_Entropy_ER_10_02_256',
#  'Image_Texture_Entropy_ER_10_03_256',
#  'Image_Texture_Entropy_ER_3_00_256',
#  'Image_Texture_Entropy_ER_3_01_256',
#  'Image_Texture_Entropy_ER_3_02_256',
#  'Image_Texture_Entropy_ER_3_03_256',
#  'Image_Texture_Entropy_ER_5_00_256',
#  'Image_Texture_Entropy_ER_5_01_256',
#  'Image_Texture_Entropy_ER_5_02_256',
#  'Image_Texture_Entropy_ER_5_03_256',
#  'Image_Texture_Entropy_Mito_10_00_256',
#  'Image_Texture_Entropy_Mito_10_01_256',
#  'Image_Texture_Entropy_Mito_10_02_256',
#  'Image_Texture_Entropy_Mito_10_03_256',
#  'Image_Texture_Entropy_Mito_3_00_256',
#  'Image_Texture_Entropy_Mito_3_01_256',
#  'Image_Texture_Entropy_Mito_3_02_256',
#  'Image_Texture_Entropy_Mito_3_03_256',
#  'Image_Texture_Entropy_Mito_5_00_256',
#  'Image_Texture_Entropy_Mito_5_01_256',
#  'Image_Texture_Entropy_Mito_5_02_256',
#  'Image_Texture_Entropy_Mito_5_03_256',
#  'Image_Texture_Entropy_RNA_10_00_256',
#  'Image_Texture_Entropy_RNA_10_01_256',
#  'Image_Texture_Entropy_RNA_10_02_256',
#  'Image_Texture_Entropy_RNA_10_03_256',
#  'Image_Texture_Entropy_RNA_3_00_256',
#  'Image_Texture_Entropy_RNA_3_01_256',
#  'Image_Texture_Entropy_RNA_3_02_256',
#  'Image_Texture_Entropy_RNA_3_03_256',
#  'Image_Texture_Entropy_RNA_5_00_256',
#  'Image_Texture_Entropy_RNA_5_01_256',
#  'Image_Texture_Entropy_RNA_5_02_256',
#  'Image_Texture_Entropy_RNA_5_03_256',
#  'Image_Texture_InfoMeas1_AGP_10_00_256',
#  'Image_Texture_InfoMeas1_AGP_10_01_256',
#  'Image_Texture_InfoMeas1_AGP_10_02_256',
#  'Image_Texture_InfoMeas1_AGP_10_03_256',
#  'Image_Texture_InfoMeas1_AGP_3_00_256',
#  'Image_Texture_InfoMeas1_AGP_3_01_256',
#  'Image_Texture_InfoMeas1_AGP_3_02_256',
#  'Image_Texture_InfoMeas1_AGP_3_03_256',
#  'Image_Texture_InfoMeas1_AGP_5_00_256',
#  'Image_Texture_InfoMeas1_AGP_5_01_256',
#  'Image_Texture_InfoMeas1_AGP_5_02_256',
#  'Image_Texture_InfoMeas1_AGP_5_03_256',
#  'Image_Texture_InfoMeas1_DNA_10_00_256',
#  'Image_Texture_InfoMeas1_DNA_10_01_256',
#  'Image_Texture_InfoMeas1_DNA_10_02_256',
#  'Image_Texture_InfoMeas1_DNA_10_03_256',
#  'Image_Texture_InfoMeas1_DNA_3_00_256',
#  'Image_Texture_InfoMeas1_DNA_3_01_256',
#  'Image_Texture_InfoMeas1_DNA_3_02_256',
#  'Image_Texture_InfoMeas1_DNA_3_03_256',
#  'Image_Texture_InfoMeas1_DNA_5_00_256',
#  'Image_Texture_InfoMeas1_DNA_5_01_256',
#  'Image_Texture_InfoMeas1_DNA_5_02_256',
#  'Image_Texture_InfoMeas1_DNA_5_03_256',
#  'Image_Texture_InfoMeas1_ER_10_00_256',
#  'Image_Texture_InfoMeas1_ER_10_01_256',
#  'Image_Texture_InfoMeas1_ER_10_02_256',
#  'Image_Texture_InfoMeas1_ER_10_03_256',
#  'Image_Texture_InfoMeas1_ER_3_00_256',
#  'Image_Texture_InfoMeas1_ER_3_01_256',
#  'Image_Texture_InfoMeas1_ER_3_02_256',
#  'Image_Texture_InfoMeas1_ER_3_03_256',
#  'Image_Texture_InfoMeas1_ER_5_00_256',
#  'Image_Texture_InfoMeas1_ER_5_01_256',
#  'Image_Texture_InfoMeas1_ER_5_02_256',
#  'Image_Texture_InfoMeas1_ER_5_03_256',
#  'Image_Texture_InfoMeas1_Mito_10_00_256',
#  'Image_Texture_InfoMeas1_Mito_10_01_256',
#  'Image_Texture_InfoMeas1_Mito_10_02_256',
#  'Image_Texture_InfoMeas1_Mito_10_03_256',
#  'Image_Texture_InfoMeas1_Mito_3_00_256',
#  'Image_Texture_InfoMeas1_Mito_3_01_256',
#  'Image_Texture_InfoMeas1_Mito_3_02_256',
#  'Image_Texture_InfoMeas1_Mito_3_03_256',
#  'Image_Texture_InfoMeas1_Mito_5_00_256',
#  'Image_Texture_InfoMeas1_Mito_5_01_256',
#  'Image_Texture_InfoMeas1_Mito_5_02_256',
#  'Image_Texture_InfoMeas1_Mito_5_03_256',
#  'Image_Texture_InfoMeas1_RNA_10_00_256',
#  'Image_Texture_InfoMeas1_RNA_10_01_256',
#  'Image_Texture_InfoMeas1_RNA_10_02_256',
#  'Image_Texture_InfoMeas1_RNA_10_03_256',
#  'Image_Texture_InfoMeas1_RNA_3_00_256',
#  'Image_Texture_InfoMeas1_RNA_3_01_256',
#  'Image_Texture_InfoMeas1_RNA_3_02_256',
#  'Image_Texture_InfoMeas1_RNA_3_03_256',
#  'Image_Texture_InfoMeas1_RNA_5_00_256',
#  'Image_Texture_InfoMeas1_RNA_5_01_256',
#  'Image_Texture_InfoMeas1_RNA_5_02_256',
#  'Image_Texture_InfoMeas1_RNA_5_03_256',
#  'Image_Texture_InfoMeas2_AGP_10_00_256',
#  'Image_Texture_InfoMeas2_AGP_10_01_256',
#  'Image_Texture_InfoMeas2_AGP_10_02_256',
#  'Image_Texture_InfoMeas2_AGP_10_03_256',
#  'Image_Texture_InfoMeas2_AGP_3_00_256',
#  'Image_Texture_InfoMeas2_AGP_3_01_256',
#  'Image_Texture_InfoMeas2_AGP_3_02_256',
#  'Image_Texture_InfoMeas2_AGP_3_03_256',
#  'Image_Texture_InfoMeas2_AGP_5_00_256',
#  'Image_Texture_InfoMeas2_AGP_5_01_256',
#  'Image_Texture_InfoMeas2_AGP_5_02_256',
#  'Image_Texture_InfoMeas2_AGP_5_03_256',
#  'Image_Texture_InfoMeas2_DNA_10_00_256',
#  'Image_Texture_InfoMeas2_DNA_10_01_256',
#  'Image_Texture_InfoMeas2_DNA_10_02_256',
#  'Image_Texture_InfoMeas2_DNA_10_03_256',
#  'Image_Texture_InfoMeas2_DNA_3_00_256',
#  'Image_Texture_InfoMeas2_DNA_3_01_256',
#  'Image_Texture_InfoMeas2_DNA_3_02_256',
#  'Image_Texture_InfoMeas2_DNA_3_03_256',
#  'Image_Texture_InfoMeas2_DNA_5_00_256',
#  'Image_Texture_InfoMeas2_DNA_5_01_256',
#  'Image_Texture_InfoMeas2_DNA_5_02_256',
#  'Image_Texture_InfoMeas2_DNA_5_03_256',
#  'Image_Texture_InfoMeas2_ER_10_00_256',
#  'Image_Texture_InfoMeas2_ER_10_01_256',
#  'Image_Texture_InfoMeas2_ER_10_02_256',
#  'Image_Texture_InfoMeas2_ER_10_03_256',
#  'Image_Texture_InfoMeas2_ER_3_00_256',
#  'Image_Texture_InfoMeas2_ER_3_01_256',
#  'Image_Texture_InfoMeas2_ER_3_02_256',
#  'Image_Texture_InfoMeas2_ER_3_03_256',
#  'Image_Texture_InfoMeas2_ER_5_00_256',
#  'Image_Texture_InfoMeas2_ER_5_01_256',
#  'Image_Texture_InfoMeas2_ER_5_02_256',
#  'Image_Texture_InfoMeas2_ER_5_03_256',
#  'Image_Texture_InfoMeas2_Mito_10_00_256',
#  'Image_Texture_InfoMeas2_Mito_10_01_256',
#  'Image_Texture_InfoMeas2_Mito_10_02_256',
#  'Image_Texture_InfoMeas2_Mito_10_03_256',
#  'Image_Texture_InfoMeas2_Mito_3_00_256',
#  'Image_Texture_InfoMeas2_Mito_3_01_256',
#  'Image_Texture_InfoMeas2_Mito_3_02_256',
#  'Image_Texture_InfoMeas2_Mito_3_03_256',
#  'Image_Texture_InfoMeas2_Mito_5_00_256',
#  'Image_Texture_InfoMeas2_Mito_5_01_256',
#  'Image_Texture_InfoMeas2_Mito_5_02_256',
#  'Image_Texture_InfoMeas2_Mito_5_03_256',
#  'Image_Texture_InfoMeas2_RNA_10_00_256',
#  'Image_Texture_InfoMeas2_RNA_10_01_256',
#  'Image_Texture_InfoMeas2_RNA_10_02_256',
#  'Image_Texture_InfoMeas2_RNA_10_03_256',
#  'Image_Texture_InfoMeas2_RNA_3_00_256',
#  'Image_Texture_InfoMeas2_RNA_3_01_256',
#  'Image_Texture_InfoMeas2_RNA_3_02_256',
#  'Image_Texture_InfoMeas2_RNA_3_03_256',
#  'Image_Texture_InfoMeas2_RNA_5_00_256',
#  'Image_Texture_InfoMeas2_RNA_5_01_256',
#  'Image_Texture_InfoMeas2_RNA_5_02_256',
#  'Image_Texture_InfoMeas2_RNA_5_03_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_10_00_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_10_01_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_10_02_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_10_03_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_3_00_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_3_01_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_3_02_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_3_03_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_5_00_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_5_01_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_5_02_256',
#  'Image_Texture_InverseDifferenceMoment_AGP_5_03_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_10_00_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_10_01_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_10_02_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_10_03_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_3_00_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_3_01_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_3_02_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_3_03_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_5_00_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_5_01_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_5_02_256',
#  'Image_Texture_InverseDifferenceMoment_DNA_5_03_256',
#  'Image_Texture_InverseDifferenceMoment_ER_10_00_256',
#  'Image_Texture_InverseDifferenceMoment_ER_10_01_256',
#  'Image_Texture_InverseDifferenceMoment_ER_10_02_256',
#  'Image_Texture_InverseDifferenceMoment_ER_10_03_256',
#  'Image_Texture_InverseDifferenceMoment_ER_3_00_256',
#  'Image_Texture_InverseDifferenceMoment_ER_3_01_256',
#  'Image_Texture_InverseDifferenceMoment_ER_3_02_256',
#  'Image_Texture_InverseDifferenceMoment_ER_3_03_256',
#  'Image_Texture_InverseDifferenceMoment_ER_5_00_256',
#  'Image_Texture_InverseDifferenceMoment_ER_5_01_256',
#  'Image_Texture_InverseDifferenceMoment_ER_5_02_256',
#  'Image_Texture_InverseDifferenceMoment_ER_5_03_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_10_00_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_10_01_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_10_02_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_10_03_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_3_00_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_3_01_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_3_02_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_3_03_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_5_00_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_5_01_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_5_02_256',
#  'Image_Texture_InverseDifferenceMoment_Mito_5_03_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_10_00_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_10_01_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_10_02_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_10_03_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_3_00_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_3_01_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_3_02_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_3_03_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_5_00_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_5_01_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_5_02_256',
#  'Image_Texture_InverseDifferenceMoment_RNA_5_03_256',
#  'Image_Texture_SumAverage_AGP_10_00_256',
#  'Image_Texture_SumAverage_AGP_10_01_256',
#  'Image_Texture_SumAverage_AGP_10_02_256',
#  'Image_Texture_SumAverage_AGP_10_03_256',
#  'Image_Texture_SumAverage_AGP_3_00_256',
#  'Image_Texture_SumAverage_AGP_3_01_256',
#  'Image_Texture_SumAverage_AGP_3_02_256',
#  'Image_Texture_SumAverage_AGP_3_03_256',
#  'Image_Texture_SumAverage_AGP_5_00_256',
#  'Image_Texture_SumAverage_AGP_5_01_256',
#  'Image_Texture_SumAverage_AGP_5_02_256',
#  'Image_Texture_SumAverage_AGP_5_03_256',
#  'Image_Texture_SumAverage_DNA_10_00_256',
#  'Image_Texture_SumAverage_DNA_10_01_256',
#  'Image_Texture_SumAverage_DNA_10_02_256',
#  'Image_Texture_SumAverage_DNA_10_03_256',
#  'Image_Texture_SumAverage_DNA_3_00_256',
#  'Image_Texture_SumAverage_DNA_3_01_256',
#  'Image_Texture_SumAverage_DNA_3_02_256',
#  'Image_Texture_SumAverage_DNA_3_03_256',
#  'Image_Texture_SumAverage_DNA_5_00_256',
#  'Image_Texture_SumAverage_DNA_5_01_256',
#  'Image_Texture_SumAverage_DNA_5_02_256',
#  'Image_Texture_SumAverage_DNA_5_03_256',
#  'Image_Texture_SumAverage_ER_10_00_256',
#  'Image_Texture_SumAverage_ER_10_01_256',
#  'Image_Texture_SumAverage_ER_10_02_256',
#  'Image_Texture_SumAverage_ER_10_03_256',
#  'Image_Texture_SumAverage_ER_3_00_256',
#  'Image_Texture_SumAverage_ER_3_01_256',
#  'Image_Texture_SumAverage_ER_3_02_256',
#  'Image_Texture_SumAverage_ER_3_03_256',
#  'Image_Texture_SumAverage_ER_5_00_256',
#  'Image_Texture_SumAverage_ER_5_01_256',
#  'Image_Texture_SumAverage_ER_5_02_256',
#  'Image_Texture_SumAverage_ER_5_03_256',
#  'Image_Texture_SumAverage_Mito_10_00_256',
#  'Image_Texture_SumAverage_Mito_10_01_256',
#  'Image_Texture_SumAverage_Mito_10_02_256',
#  'Image_Texture_SumAverage_Mito_10_03_256',
#  'Image_Texture_SumAverage_Mito_3_00_256',
#  'Image_Texture_SumAverage_Mito_3_01_256',
#  'Image_Texture_SumAverage_Mito_3_02_256',
#  'Image_Texture_SumAverage_Mito_3_03_256',
#  'Image_Texture_SumAverage_Mito_5_00_256',
#  'Image_Texture_SumAverage_Mito_5_01_256',
#  'Image_Texture_SumAverage_Mito_5_02_256',
#  'Image_Texture_SumAverage_Mito_5_03_256',
#  'Image_Texture_SumAverage_RNA_10_00_256',
#  'Image_Texture_SumAverage_RNA_10_01_256',
#  'Image_Texture_SumAverage_RNA_10_02_256',
#  'Image_Texture_SumAverage_RNA_10_03_256',
#  'Image_Texture_SumAverage_RNA_3_00_256',
#  'Image_Texture_SumAverage_RNA_3_01_256',
#  'Image_Texture_SumAverage_RNA_3_02_256',
#  'Image_Texture_SumAverage_RNA_3_03_256',
#  'Image_Texture_SumAverage_RNA_5_00_256',
#  'Image_Texture_SumAverage_RNA_5_01_256',
#  'Image_Texture_SumAverage_RNA_5_02_256',
#  'Image_Texture_SumAverage_RNA_5_03_256',
#  'Image_Texture_SumEntropy_AGP_10_00_256',
#  'Image_Texture_SumEntropy_AGP_10_01_256',
#  'Image_Texture_SumEntropy_AGP_10_02_256',
#  'Image_Texture_SumEntropy_AGP_10_03_256',
#  'Image_Texture_SumEntropy_AGP_3_00_256',
#  'Image_Texture_SumEntropy_AGP_3_01_256',
#  'Image_Texture_SumEntropy_AGP_3_02_256',
#  'Image_Texture_SumEntropy_AGP_3_03_256',
#  'Image_Texture_SumEntropy_AGP_5_00_256',
#  'Image_Texture_SumEntropy_AGP_5_01_256',
#  'Image_Texture_SumEntropy_AGP_5_02_256',
#  'Image_Texture_SumEntropy_AGP_5_03_256',
#  'Image_Texture_SumEntropy_DNA_10_00_256',
#  'Image_Texture_SumEntropy_DNA_10_01_256',
#  'Image_Texture_SumEntropy_DNA_10_02_256',
#  'Image_Texture_SumEntropy_DNA_10_03_256',
#  'Image_Texture_SumEntropy_DNA_3_00_256',
#  'Image_Texture_SumEntropy_DNA_3_01_256',
#  'Image_Texture_SumEntropy_DNA_3_02_256',
#  'Image_Texture_SumEntropy_DNA_3_03_256',
#  'Image_Texture_SumEntropy_DNA_5_00_256',
#  'Image_Texture_SumEntropy_DNA_5_01_256',
#  'Image_Texture_SumEntropy_DNA_5_02_256',
#  'Image_Texture_SumEntropy_DNA_5_03_256',
#  'Image_Texture_SumEntropy_ER_10_00_256',
#  'Image_Texture_SumEntropy_ER_10_01_256',
#  'Image_Texture_SumEntropy_ER_10_02_256',
#  'Image_Texture_SumEntropy_ER_10_03_256',
#  'Image_Texture_SumEntropy_ER_3_00_256',
#  'Image_Texture_SumEntropy_ER_3_01_256',
#  'Image_Texture_SumEntropy_ER_3_02_256',
#  'Image_Texture_SumEntropy_ER_3_03_256',
#  'Image_Texture_SumEntropy_ER_5_00_256',
#  'Image_Texture_SumEntropy_ER_5_01_256',
#  'Image_Texture_SumEntropy_ER_5_02_256',
#  'Image_Texture_SumEntropy_ER_5_03_256',
#  'Image_Texture_SumEntropy_Mito_10_00_256',
#  'Image_Texture_SumEntropy_Mito_10_01_256',
#  'Image_Texture_SumEntropy_Mito_10_02_256',
#  'Image_Texture_SumEntropy_Mito_10_03_256',
#  'Image_Texture_SumEntropy_Mito_3_00_256',
#  'Image_Texture_SumEntropy_Mito_3_01_256',
#  'Image_Texture_SumEntropy_Mito_3_02_256',
#  'Image_Texture_SumEntropy_Mito_3_03_256',
#  'Image_Texture_SumEntropy_Mito_5_00_256',
#  'Image_Texture_SumEntropy_Mito_5_01_256',
#  'Image_Texture_SumEntropy_Mito_5_02_256',
#  'Image_Texture_SumEntropy_Mito_5_03_256',
#  'Image_Texture_SumEntropy_RNA_10_00_256',
#  'Image_Texture_SumEntropy_RNA_10_01_256',
#  'Image_Texture_SumEntropy_RNA_10_02_256',
#  'Image_Texture_SumEntropy_RNA_10_03_256',
#  'Image_Texture_SumEntropy_RNA_3_00_256',
#  'Image_Texture_SumEntropy_RNA_3_01_256',
#  'Image_Texture_SumEntropy_RNA_3_02_256',
#  'Image_Texture_SumEntropy_RNA_3_03_256',
#  'Image_Texture_SumEntropy_RNA_5_00_256',
#  'Image_Texture_SumEntropy_RNA_5_01_256',
#  'Image_Texture_SumEntropy_RNA_5_02_256',
#  'Image_Texture_SumEntropy_RNA_5_03_256',
#  'Image_Texture_SumVariance_AGP_10_00_256',
#  'Image_Texture_SumVariance_AGP_10_01_256',
#  'Image_Texture_SumVariance_AGP_10_02_256',
#  'Image_Texture_SumVariance_AGP_10_03_256',
#  'Image_Texture_SumVariance_AGP_3_00_256',
#  'Image_Texture_SumVariance_AGP_3_01_256',
#  'Image_Texture_SumVariance_AGP_3_02_256',
#  'Image_Texture_SumVariance_AGP_3_03_256',
#  'Image_Texture_SumVariance_AGP_5_00_256',
#  'Image_Texture_SumVariance_AGP_5_01_256',
#  'Image_Texture_SumVariance_AGP_5_02_256',
#  'Image_Texture_SumVariance_AGP_5_03_256',
#  'Image_Texture_SumVariance_DNA_10_00_256',
#  'Image_Texture_SumVariance_DNA_10_01_256',
#  'Image_Texture_SumVariance_DNA_10_02_256',
#  'Image_Texture_SumVariance_DNA_10_03_256',
#  'Image_Texture_SumVariance_DNA_3_00_256',
#  'Image_Texture_SumVariance_DNA_3_01_256',
#  'Image_Texture_SumVariance_DNA_3_02_256',
#  'Image_Texture_SumVariance_DNA_3_03_256',
#  'Image_Texture_SumVariance_DNA_5_00_256',
#  'Image_Texture_SumVariance_DNA_5_01_256',
#  'Image_Texture_SumVariance_DNA_5_02_256',
#  'Image_Texture_SumVariance_DNA_5_03_256',
#  'Image_Texture_SumVariance_ER_10_00_256',
#  'Image_Texture_SumVariance_ER_10_01_256',
#  'Image_Texture_SumVariance_ER_10_02_256',
#  'Image_Texture_SumVariance_ER_10_03_256',
#  'Image_Texture_SumVariance_ER_3_00_256',
#  'Image_Texture_SumVariance_ER_3_01_256',
#  'Image_Texture_SumVariance_ER_3_02_256',
#  'Image_Texture_SumVariance_ER_3_03_256',
#  'Image_Texture_SumVariance_ER_5_00_256',
#  'Image_Texture_SumVariance_ER_5_01_256',
#  ...]

# %% [markdown]
# Do we have to minmaxscale per plate?
#
# What to analyse plate effects?
# - All metadata columns
# - Per channel/other thing PCA
# - Show which columns differ most by plate positioning
# - Representative columns per channel?
# - Overal most variance?
#
# First only for DMSO plate
# All different channels
# All positioning columns to look at
# Most variance columns
#
# Ten for compound plate
#
# Variance to measure
# 1. Within Plates
# 2. Between plates of the same week
# 3. Confocal non-confocal
# 4. Between weeks
